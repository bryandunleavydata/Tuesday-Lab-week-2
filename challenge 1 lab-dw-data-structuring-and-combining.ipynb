# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100
## Install xlrd package to load Excel files
#!conda install openpyxl
#!conda install xlrd

# %%
file2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')

# %%
# Rename the 'st' column to 'state'
file2 = file2.rename(columns={'st': 'state'})

# %%
low2 = low2.drop('middle_part', axis=1)

# %%
low2 = lower_case_column_names(file2)
low2
# Out:
#     customer       state gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
low2['number of open complaints'] = low2['number of open complaints'].apply(lambda x: np.nan if pd.isna(x) else x.split('/')[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 low2['number of open complaints'] = low2['number of open complaints'].apply(lambda x: np.nan if pd.isna(x) else x.split('/')[1])
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# ...

# %%
file3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')

# %%
low2 = low2.drop('middle_part', axis=1)

# %%
def lower_case_column_names(file3):
    file3.columns=[i.lower() for i in file3.columns]
    return file3

# %%
low3 = lower_case_column_names(file3)
low3
# Out:
#      customer       state gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value  income  monthly premium auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
# Define the desired column order
desired_columns = ['customer', 'state', 'gender', 'education', 'customer lifetime value', 'income',
                   'monthly premium auto', 'number of open complaints', 'total claim amount',
                   'policy type', 'vehicle class']

# Reindex the columns of the DataFrame
low3 = low3.reindex(columns=desired_columns)

# %%
concatenated23 = pd.concat([low2, low3], axis=0)

# %%
concatenated23
# Out:
#      customer       state gender education customer lifetime value  income  \
# 0     GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1     CW49887  California      F    Master              462680.11%   79487
# 2     MY31220  California      F   College              899704.02%   54230
# 3     UH35128      Oregon      F   College             2580706.30%   71210
# 4     WH52799     Arizona      F   College              380812.21%   94903
# ...       ...         ...    ...       ...                     ...     ...
# 7065  LA72316  California      M  Bachelor             23405.98798   71941
# 7066  PK87824  California      F   College             3096.511217   21604
# 7067  TD14365  California      M  Bachelor             8163.890428       0
# 7068  UP19263  California      M   College             7524.442436   21941
# 7069  Y167826  California      M   College             2611.836866       0
#
# ...

# %%
concatenated23 = concatenated23.drop('middle_part', axis=1)

# %%
concatenated23
# Out:
#      customer       state gender education customer lifetime value  income  \
# 0     GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1     CW49887  California      F    Master              462680.11%   79487
# 2     MY31220  California      F   College              899704.02%   54230
# 3     UH35128      Oregon      F   College             2580706.30%   71210
# 4     WH52799     Arizona      F   College              380812.21%   94903
# ...       ...         ...    ...       ...                     ...     ...
# 7065  LA72316  California      M  Bachelor             23405.98798   71941
# 7066  PK87824  California      F   College             3096.511217   21604
# 7067  TD14365  California      M  Bachelor             8163.890428       0
# 7068  UP19263  California      M   College             7524.442436   21941
# 7069  Y167826  California      M   College             2611.836866       0
#
# ...

# %%
concatenated23['customer lifetime value'] = concatenated23['customer lifetime value'].str.replace('%', '').astype(float)

# %%
concatenated23
# Out:
#      customer       state gender education  customer lifetime value  income  \
# 0     GS98873     Arizona      F  Bachelor                323912.47   16061
# 1     CW49887  California      F    Master                462680.11   79487
# 2     MY31220  California      F   College                899704.02   54230
# 3     UH35128      Oregon      F   College               2580706.30   71210
# 4     WH52799     Arizona      F   College                380812.21   94903
# ...       ...         ...    ...       ...                      ...     ...
# 7065  LA72316  California      M  Bachelor                      NaN   71941
# 7066  PK87824  California      F   College                      NaN   21604
# 7067  TD14365  California      M  Bachelor                      NaN       0
# 7068  UP19263  California      M   College                      NaN   21941
# 7069  Y167826  California      M   College                      NaN       0
#
# ...

# %%
column_mapping = {
    'customer': str,
    'state': str,
    'gender': str,
    'education': str,
    'customer lifetime value': float,
    'income': float,
    'monthly premium auto': float,
    'number of open complaints': float,
    'policy type': str,
    'vehicle class': str,
    'total claim amount': float
}

# %%
concatenated23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8066 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   8066 non-null   object
#  1   state                      8066 non-null   object
#  2   gender                     8061 non-null   object
#  3   education                  8066 non-null   object
#  4   customer lifetime value    992 non-null    float64
#  5   income                     8066 non-null   int64
#  6   monthly premium auto       8066 non-null   int64
#  7   number of open complaints  8066 non-null   object
#  8   total claim amount         8066 non-null   float64
#  9   policy type                8066 non-null   object
#  10  vehicle class              8066 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 756.2+ KB

# %%
file1 = pd.read_csv('file1_dropped.csv')

# %%
# Out:
#            id    location  gender             education  lifetime_value  \
# 0     RB50392  Washington  Female                Master             NaN
# 1     QZ44356     Arizona  Female              Bachelor       697953.59
# 2     AI49188      Nevada  Female              Bachelor      1288743.17
# 3     WW63253  California    Male              Bachelor       764586.18
# 4     GA49547  Washington    Male  High School or Below       536307.65
# ...       ...         ...     ...                   ...             ...
# 1066  TM65736      Oregon    Male                Master       305955.03
# 1067  VJ51327  California  Female  High School or Below      2031499.76
# 1068  GS98873     Arizona  Female              Bachelor       323912.47
# 1069  CW49887  California  Female                Master       462680.11
# 1070  MY31220  California  Female               College       899704.02
#
#        income  premium open_complaints          policy        vehicle  \
# ...

# %%
customer_data = pd.concat([concatenated23,file1], axis=0)

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1071 entries, 0 to 1070
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   0 non-null      float64
#  1   state                      0 non-null      float64
#  2   gender                     1071 non-null   object
#  3   education                  1071 non-null   object
#  4   customer lifetime value    0 non-null      float64
#  5   income                     1071 non-null   float64
#  6   monthly premium auto       0 non-null      float64
#  7   number of open complaints  0 non-null      float64
#  8   total claim amount         0 non-null      float64
#  9   policy type                0 non-null      float64
#  10  vehicle class              0 non-null      float64
# dtypes: float64(9), object(2)
# memory usage: 92.2+ KB

# %%
customer_data
# Out:
#      customer       state  gender             education  \
# 0     GS98873     Arizona       F              Bachelor
# 1     CW49887  California       F                Master
# 2     MY31220  California       F               College
# 3     UH35128      Oregon       F               College
# 4     WH52799     Arizona       F               College
# ...       ...         ...     ...                   ...
# 1066      NaN         NaN    Male                Master
# 1067      NaN         NaN  Female  High School or Below
# 1068      NaN         NaN  Female              Bachelor
# 1069      NaN         NaN  Female                Master
# 1070      NaN         NaN  Female               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                   323912.47  16061.0                  88.0
# 1                   462680.11  79487.0                 114.0
# 2                   899704.02  54230.0                 112.0
# ...

# %%
concatenated23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8066 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   8066 non-null   object
#  1   state                      8066 non-null   object
#  2   gender                     8061 non-null   object
#  3   education                  8066 non-null   object
#  4   customer lifetime value    992 non-null    float64
#  5   income                     8066 non-null   int64
#  6   monthly premium auto       8066 non-null   int64
#  7   number of open complaints  8066 non-null   object
#  8   total claim amount         8066 non-null   float64
#  9   policy type                8066 non-null   object
#  10  vehicle class              8066 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 756.2+ KB

# %%
# Define the desired column order
desired_columns_file1 = ['customer', 'state', 'gender', 'education', 'customer lifetime value', 'income',
                   'monthly premium auto', 'number of open complaints', 'total claim amount',
                   'policy type', 'vehicle class']

# Reindex the columns of the DataFrame
file1 = file1.reindex(columns=desired_columns)

# %%
threshold = 8
columns_to_check = ['customer', 'state', 'gender', 'education', 'customer lifetime value', 'income',
                   'monthly premium auto', 'number of open complaints', 'total claim amount',
                   'policy type', 'vehicle class']

file1_dropped = file1.dropna(subset=columns_to_check, thresh=file1.shape[1] - threshold)

# %%
threshold = 8
columns_to_check = ['customer', 'state', 'gender', 'education', 'customer lifetime value', 'income',
                   'monthly premium auto', 'number of open complaints', 'total claim amount',
                   'policy type', 'vehicle class']

con23_dropped = concatenated23.dropna(subset=columns_to_check, thresh=concatenated23.shape[1] - threshold)

# %%
con23_dropped
# Out:
#      customer       state gender education  customer lifetime value  income  \
# 0     GS98873     Arizona      F  Bachelor                323912.47   16061
# 1     CW49887  California      F    Master                462680.11   79487
# 2     MY31220  California      F   College                899704.02   54230
# 3     UH35128      Oregon      F   College               2580706.30   71210
# 4     WH52799     Arizona      F   College                380812.21   94903
# ...       ...         ...    ...       ...                      ...     ...
# 7065  LA72316  California      M  Bachelor                      NaN   71941
# 7066  PK87824  California      F   College                      NaN   21604
# 7067  TD14365  California      M  Bachelor                      NaN       0
# 7068  UP19263  California      M   College                      NaN   21941
# 7069  Y167826  California      M   College                      NaN       0
#
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8066 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   8066 non-null   object
#  1   state                      8066 non-null   object
#  2   gender                     8061 non-null   object
#  3   education                  8066 non-null   object
#  4   customer lifetime value    992 non-null    float64
#  5   income                     8066 non-null   int64
#  6   monthly premium auto       8066 non-null   int64
#  7   number of open complaints  8066 non-null   object
#  8   total claim amount         8066 non-null   float64
#  9   policy type                8066 non-null   object
#  10  vehicle class              8066 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 756.2+ KB

# %%
con23_dropped.gender.value_counts()
# Out:
# F    4105
# M    3956
# Name: gender, dtype: int64

# %%
def clean_gender(x):
    if x in ['M', 'Male']:
        return 'M'
    elif x in ['F', '', 'female']:
        return 'F'
    else:
        return np.nan

con23_dropped['gender'] = con23_dropped['gender'].apply(clean_gender)

# %%
con23_dropped['customer lifetime value'].describe()
# Out:
# count    8.066000e+03
# mean     7.651494e+05
# std      2.178470e+05
# min      2.004351e+05
# 25%      7.651494e+05
# 50%      7.651494e+05
# 75%      7.651494e+05
# max      4.922143e+06
# Name: customer lifetime value, dtype: float64

# %%
number1 = 8.066000e+03
count_clv = '{:.2f}'.format(number1)

number2 = 7.651494e+05
mean_clv = '{:.2f}'.format(number2)

number3 = 2.178470e+05
std_clv = '{:.2f}'.format(number3)

number4 = 2.004351e+05
min_clv = '{:.2f}'.format(number4)

number5 = 4.034080e+05
quart_clv = '{:.2f}'.format(number5)

number6 = 5.627054e+05
med_clv = '{:.2f}'.format(number6)

number7 = 8.690526e+05
thirdquart_clv = '{:.2f}'.format(number7)

number8 = 4.922143e+06
max_clv = '{:.2f}'.format(number8)

print("count:",count_clv)
print("mean:",mean_clv)
print("std:",std_clv)
print("minimum value:",min_clv)
print("25th percentile:",quart_clv)
print("median:",med_clv)
print("75th percentile:",thirdquart_clv)
print("maximum value:",max_clv)
# Out:
# count: 8066.00
# mean: 765149.40
# std: 217847.00
# minimum value: 200435.10
# 25th percentile: 403408.00
# median: 562705.40
# 75th percentile: 869052.60
# maximum value: 4922143.00

# %%
mean_value = con23_dropped['customer lifetime value'].mean()
con23_dropped['customer lifetime value'].fillna(mean_value, inplace=True)

# %%
final_data = con23_dropped

# %%
final_data.to_csv('final_data.csv', index=False)
